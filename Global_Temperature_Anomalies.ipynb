# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import missingno as msno
# %matplotlib inline

# %%
df = pd.read_csv('Global Temperature Anomalies.csv')

# %%
df
# Out:
#     Hemisphere  Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0       Global  1880 -0.17 -0.23 -0.08 -0.15 -0.08 -0.20 -0.17 -0.09 -0.13
# 1       Global  1881 -0.18 -0.13  0.04  0.06  0.08 -0.17  0.02 -0.02 -0.14
# 2       Global  1882  0.18  0.15  0.06 -0.15 -0.13 -0.21 -0.15 -0.06 -0.13
# 3       Global  1883 -0.28 -0.36 -0.11 -0.17 -0.16 -0.07 -0.05 -0.12 -0.20
# 4       Global  1884 -0.12 -0.07 -0.36 -0.39 -0.33 -0.34 -0.32 -0.27 -0.26
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 418   Southern  2016  0.80  0.79  0.79  0.74  0.81  0.51  0.67  0.92  0.60
# 419   Southern  2017  0.65  0.76  0.80  0.69  0.90  0.53  0.67  0.73  0.55
# 420   Southern  2018  0.48  0.45  0.61  0.80  0.63  0.69  0.75  0.65  0.64
# 421   Southern  2019  0.66  0.78  0.80  0.77  0.73  0.65  0.86  0.79  0.64
# 422   Southern  2020  0.74  0.78  0.68  0.86  0.76  0.71  0.69  0.62  0.78
#
#       Oct   Nov   Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0   -0.22 -0.20 -0.16 -0.16   NaN   NaN -0.10 -0.15 -0.18
# 1   -0.20 -0.17 -0.05 -0.07 -0.08 -0.16  0.06 -0.06 -0.17
# 2   -0.23 -0.15 -0.34 -0.10 -0.07  0.09 -0.08 -0.14 -0.17
# 3   -0.10 -0.22 -0.10 -0.16 -0.18 -0.33 -0.15 -0.08 -0.17
# 4   -0.24 -0.32 -0.30 -0.28 -0.26 -0.10 -0.36 -0.31 -0.27
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 418  0.74  0.70  0.69  0.73  0.74  0.79  0.78  0.70  0.68
# 419  0.75  0.53  0.47  0.67  0.69  0.70  0.80  0.64  0.61
# 420  0.79  0.69  0.74  0.66  0.64  0.47  0.68  0.70  0.71
# 421  0.72  0.81  0.79  0.75  0.75  0.73  0.77  0.77  0.72
# 422  0.56  0.60  0.43  0.69  0.71  0.77  0.77  0.68  0.65
#
# [423 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hemisphere  423 non-null    object
#  1   Year        423 non-null    int64
#  2   Jan         423 non-null    float64
#  3   Feb         423 non-null    float64
#  4   Mar         423 non-null    float64
#  5   Apr         423 non-null    float64
#  6   May         423 non-null    float64
#  7   Jun         423 non-null    float64
#  8   Jul         423 non-null    float64
#  9   Aug         423 non-null    float64
#  10  Sep         423 non-null    float64
#  11  Oct         423 non-null    float64
#  12  Nov         423 non-null    float64
#  13  Dec         423 non-null    float64
#  14  J-D         423 non-null    float64
#  15  D-N         420 non-null    float64
#  16  DJF         420 non-null    float64
#  17  MAM         423 non-null    float64
#  18  JJA         423 non-null    float64
#  19  SON         423 non-null    float64
# dtypes: float64(18), int64(1), object(1)
# memory usage: 66.2+ KB

# %%
df= df.dropna(axis=1)

# %%
df.isnull().sum()
# Out:
# Hemisphere    0
# Year          0
# Jan           0
# Feb           0
# Mar           0
# Apr           0
# May           0
# Jun           0
# Jul           0
# Aug           0
# Sep           0
# Oct           0
# Nov           0
# Dec           0
# J-D           0
# MAM           0
# JJA           0
# SON           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Hemisphere', 'Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',
#        'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'J-D', 'MAM', 'JJA', 'SON'],
#       dtype='object')

# %%
df= df.drop(columns=['J-D', 'MAM', 'JJA', 'SON'])

# %%
df
# Out:
#     Hemisphere  Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0       Global  1880 -0.17 -0.23 -0.08 -0.15 -0.08 -0.20 -0.17 -0.09 -0.13
# 1       Global  1881 -0.18 -0.13  0.04  0.06  0.08 -0.17  0.02 -0.02 -0.14
# 2       Global  1882  0.18  0.15  0.06 -0.15 -0.13 -0.21 -0.15 -0.06 -0.13
# 3       Global  1883 -0.28 -0.36 -0.11 -0.17 -0.16 -0.07 -0.05 -0.12 -0.20
# 4       Global  1884 -0.12 -0.07 -0.36 -0.39 -0.33 -0.34 -0.32 -0.27 -0.26
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 418   Southern  2016  0.80  0.79  0.79  0.74  0.81  0.51  0.67  0.92  0.60
# 419   Southern  2017  0.65  0.76  0.80  0.69  0.90  0.53  0.67  0.73  0.55
# 420   Southern  2018  0.48  0.45  0.61  0.80  0.63  0.69  0.75  0.65  0.64
# 421   Southern  2019  0.66  0.78  0.80  0.77  0.73  0.65  0.86  0.79  0.64
# 422   Southern  2020  0.74  0.78  0.68  0.86  0.76  0.71  0.69  0.62  0.78
#
#       Oct   Nov   Dec
# 0   -0.22 -0.20 -0.16
# 1   -0.20 -0.17 -0.05
# 2   -0.23 -0.15 -0.34
# 3   -0.10 -0.22 -0.10
# 4   -0.24 -0.32 -0.30
# ..    ...   ...   ...
# 418  0.74  0.70  0.69
# 419  0.75  0.53  0.47
# 420  0.79  0.69  0.74
# 421  0.72  0.81  0.79
# 422  0.56  0.60  0.43
#
# [423 rows x 14 columns]

# %%
df = df[df['Hemisphere']=='Global'] #condition

# %%
df
# Out:
#     Hemisphere  Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0       Global  1880 -0.17 -0.23 -0.08 -0.15 -0.08 -0.20 -0.17 -0.09 -0.13
# 1       Global  1881 -0.18 -0.13  0.04  0.06  0.08 -0.17  0.02 -0.02 -0.14
# 2       Global  1882  0.18  0.15  0.06 -0.15 -0.13 -0.21 -0.15 -0.06 -0.13
# 3       Global  1883 -0.28 -0.36 -0.11 -0.17 -0.16 -0.07 -0.05 -0.12 -0.20
# 4       Global  1884 -0.12 -0.07 -0.36 -0.39 -0.33 -0.34 -0.32 -0.27 -0.26
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 136     Global  2016  1.17  1.37  1.35  1.12  0.96  0.81  0.85  1.02  0.91
# 137     Global  2017  1.03  1.15  1.17  0.95  0.91  0.72  0.82  0.87  0.77
# 138     Global  2018  0.82  0.85  0.90  0.89  0.83  0.78  0.83  0.76  0.81
# 139     Global  2019  0.94  0.96  1.18  1.02  0.86  0.93  0.95  0.94  0.93
# 140     Global  2020  1.17  1.26  1.18  1.14  1.02  0.92  0.90  0.87  0.99
#
#       Oct   Nov   Dec
# 0   -0.22 -0.20 -0.16
# 1   -0.20 -0.17 -0.05
# 2   -0.23 -0.15 -0.34
# 3   -0.10 -0.22 -0.10
# 4   -0.24 -0.32 -0.30
# ..    ...   ...   ...
# 136  0.89  0.91  0.86
# 137  0.90  0.88  0.94
# 138  1.02  0.83  0.92
# 139  1.02  1.01  1.09
# 140  0.89  1.11  0.81
#
# [141 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['Hemisphere', 'Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',
#        'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
df['Yearly Mean'] = df[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',
       'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].mean(axis=1) #creating a new column with the yearly mean
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#     Hemisphere  Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0       Global  1880 -0.17 -0.23 -0.08 -0.15 -0.08 -0.20 -0.17 -0.09 -0.13
# 1       Global  1881 -0.18 -0.13  0.04  0.06  0.08 -0.17  0.02 -0.02 -0.14
# 2       Global  1882  0.18  0.15  0.06 -0.15 -0.13 -0.21 -0.15 -0.06 -0.13
# 3       Global  1883 -0.28 -0.36 -0.11 -0.17 -0.16 -0.07 -0.05 -0.12 -0.20
# 4       Global  1884 -0.12 -0.07 -0.36 -0.39 -0.33 -0.34 -0.32 -0.27 -0.26
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 136     Global  2016  1.17  1.37  1.35  1.12  0.96  0.81  0.85  1.02  0.91
# 137     Global  2017  1.03  1.15  1.17  0.95  0.91  0.72  0.82  0.87  0.77
# 138     Global  2018  0.82  0.85  0.90  0.89  0.83  0.78  0.83  0.76  0.81
# 139     Global  2019  0.94  0.96  1.18  1.02  0.86  0.93  0.95  0.94  0.93
# 140     Global  2020  1.17  1.26  1.18  1.14  1.02  0.92  0.90  0.87  0.99
#
#       Oct   Nov   Dec  Yearly Mean
# 0   -0.22 -0.20 -0.16    -0.156667
# 1   -0.20 -0.17 -0.05    -0.071667
# 2   -0.23 -0.15 -0.34    -0.096667
# 3   -0.10 -0.22 -0.10    -0.161667
# 4   -0.24 -0.32 -0.30    -0.276667
# ..    ...   ...   ...          ...
# 136  0.89  0.91  0.86     1.018333
# 137  0.90  0.88  0.94     0.925833
# 138  1.02  0.83  0.92     0.853333
# 139  1.02  1.01  1.09     0.985833
# 140  0.89  1.11  0.81     1.021667
#
# [141 rows x 15 columns]

# %%
df1 = df[['Yearly Mean','Year']].copy() #creating a copy of the df for the viz

# %%
df1['Yearly Average above/below baseline °C']= df1['Yearly Mean'].round(decimals=3)

# %%
import plotly.express as px
fig = px.bar_polar(df1, r='Yearly Average above/below baseline °C', template="plotly_dark",color='Yearly Average above/below baseline °C',hover_name='Year',
                   color_discrete_sequence= px.colors.sequential.Plasma_r,start_angle = 90, log_r = False,title ='Global temperature anomalies compared to baseline, from 1880 to 2020',width=1620, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="21734238-980c-45fd-bc53-3c52bf47aca7" class="plotly-graph-div" style="height:800px; width:1620px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21734238-980c-45fd-bc53-3c52bf47aca7")) {                    Plotly.newPlot(                        "21734238-980c-45fd-bc53-3c52bf47aca7",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Yearly Average above/below baseline \u00b0C=%{marker.color}<extra></extra>","hovertext":[1880.0,1881.0,1882.0,1883.0,1884.0,1885.0,1886.0,1887.0,1888.0,1889.0,1890.0,1891.0,1892.0,1893.0,1894.0,1895.0,1896.0,1897.0,1898.0,1899.0,1900.0,1901.0,1902.0,1903.0,1904.0,1905.0,1906.0,1907.0,1908.0,1909.0,1910.0,1911.0,1912.0,1913.0,1914.0,1915.0,1916.0,1917.0,1918.0,1919.0,1920.0,1921.0,1922.0,1923.0,1924.0,1925.0,1926.0,1927.0,1928.0,1929.0,1930.0,1931.0,1932.0,1933.0,1934.0,1935.0,1936.0,1937.0,1938.0,1939.0,1940.0,1941.0,1942.0,1943.0,1944.0,1945.0,1946.0,1947.0,1948.0,1949.0,1950.0,1951.0,1952.0,1953.0,1954.0,1955.0,1956.0,1957.0,1958.0,1959.0,1960.0,1961.0,1962.0,1963.0,1964.0,1965.0,1966.0,1967.0,1968.0,1969.0,1970.0,1971.0,1972.0,1973.0,1974.0,1975.0,1976.0,1977.0,1978.0,1979.0,1980.0,1981.0,1982.0,1983.0,1984.0,1985.0,1986.0,1987.0,1988.0,1989.0,1990.0,1991.0,1992.0,1993.0,1994.0,1995.0,1996.0,1997.0,1998.0,1999.0,2000.0,2001.0,2002.0,2003.0,2004.0,2005.0,2006.0,2007.0,2008.0,2009.0,2010.0,2011.0,2012.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0],"legendgroup":"","marker":{"color":[-0.157,-0.072,-0.097,-0.162,-0.277,-0.325,-0.305,-0.354,-0.167,-0.102,-0.345,-0.222,-0.269,-0.309,-0.299,-0.22,-0.108,-0.105,-0.264,-0.169,-0.073,-0.148,-0.269,-0.36,-0.46,-0.256,-0.217,-0.378,-0.42,-0.477,-0.424,-0.431,-0.349,-0.337,-0.144,-0.133,-0.349,-0.45,-0.29,-0.269,-0.266,-0.183,-0.278,-0.26,-0.265,-0.215,-0.104,-0.215,-0.196,-0.356,-0.155,-0.092,-0.16,-0.286,-0.122,-0.198,-0.148,-0.026,-0.003,-0.018,0.125,0.185,0.065,0.088,0.203,0.09,-0.074,-0.028,-0.107,-0.109,-0.174,-0.069,0.011,0.079,-0.132,-0.141,-0.189,0.047,0.06,0.03,-0.025,0.057,0.031,0.054,-0.2,-0.107,-0.055,-0.023,-0.084,0.055,0.025,-0.082,0.008,0.161,-0.068,-0.014,-0.097,0.178,0.068,0.165,0.259,0.322,0.141,0.314,0.157,0.118,0.18,0.323,0.39,0.273,0.452,0.406,0.22,0.234,0.316,0.446,0.328,0.464,0.609,0.383,0.395,0.54,0.628,0.62,0.539,0.682,0.643,0.668,0.546,0.66,0.725,0.61,0.646,0.682,0.751,0.901,1.018,0.926,0.853,0.986,1.022],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","r":[-0.157,-0.072,-0.097,-0.162,-0.277,-0.325,-0.305,-0.354,-0.167,-0.102,-0.345,-0.222,-0.269,-0.309,-0.299,-0.22,-0.108,-0.105,-0.264,-0.169,-0.073,-0.148,-0.269,-0.36,-0.46,-0.256,-0.217,-0.378,-0.42,-0.477,-0.424,-0.431,-0.349,-0.337,-0.144,-0.133,-0.349,-0.45,-0.29,-0.269,-0.266,-0.183,-0.278,-0.26,-0.265,-0.215,-0.104,-0.215,-0.196,-0.356,-0.155,-0.092,-0.16,-0.286,-0.122,-0.198,-0.148,-0.026,-0.003,-0.018,0.125,0.185,0.065,0.088,0.203,0.09,-0.074,-0.028,-0.107,-0.109,-0.174,-0.069,0.011,0.079,-0.132,-0.141,-0.189,0.047,0.06,0.03,-0.025,0.057,0.031,0.054,-0.2,-0.107,-0.055,-0.023,-0.084,0.055,0.025,-0.082,0.008,0.161,-0.068,-0.014,-0.097,0.178,0.068,0.165,0.259,0.322,0.141,0.314,0.157,0.118,0.18,0.323,0.39,0.273,0.452,0.406,0.22,0.234,0.316,0.446,0.328,0.464,0.609,0.383,0.395,0.54,0.628,0.62,0.539,0.682,0.643,0.668,0.546,0.66,0.725,0.61,0.646,0.682,0.751,0.901,1.018,0.926,0.853,0.986,1.022],"showlegend":false,"subplot":"polar","type":"barpolar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"sol ...

# %%
fig.update_layout(
    polar = dict(
      angularaxis = dict(
            tickvals=[7, 45, 90, 135, 180, 225, 270, 315, 356],
            ticktext=["1880", "1898", "1915", "1933", "1951", "1969", "1986", "2003","2020"],
            showgrid=False, showline=False, showticklabels=True, layer='below traces',
            color="antiquewhite",ticks=""
            ),
    radialaxis = dict(showgrid=True, showline=True,showticklabels=True, linecolor="#3c3b54",gridcolor="#3c3b54",color='antiquewhite',side='clockwise',tickangle=0,type='-',ticks="outside")


    ))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="512ca190-2bc0-4c58-8110-a86dc3d750a4" class="plotly-graph-div" style="height:800px; width:1620px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("512ca190-2bc0-4c58-8110-a86dc3d750a4")) {                    Plotly.newPlot(                        "512ca190-2bc0-4c58-8110-a86dc3d750a4",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Yearly Average above/below baseline \u00b0C=%{marker.color}<extra></extra>","hovertext":[1880.0,1881.0,1882.0,1883.0,1884.0,1885.0,1886.0,1887.0,1888.0,1889.0,1890.0,1891.0,1892.0,1893.0,1894.0,1895.0,1896.0,1897.0,1898.0,1899.0,1900.0,1901.0,1902.0,1903.0,1904.0,1905.0,1906.0,1907.0,1908.0,1909.0,1910.0,1911.0,1912.0,1913.0,1914.0,1915.0,1916.0,1917.0,1918.0,1919.0,1920.0,1921.0,1922.0,1923.0,1924.0,1925.0,1926.0,1927.0,1928.0,1929.0,1930.0,1931.0,1932.0,1933.0,1934.0,1935.0,1936.0,1937.0,1938.0,1939.0,1940.0,1941.0,1942.0,1943.0,1944.0,1945.0,1946.0,1947.0,1948.0,1949.0,1950.0,1951.0,1952.0,1953.0,1954.0,1955.0,1956.0,1957.0,1958.0,1959.0,1960.0,1961.0,1962.0,1963.0,1964.0,1965.0,1966.0,1967.0,1968.0,1969.0,1970.0,1971.0,1972.0,1973.0,1974.0,1975.0,1976.0,1977.0,1978.0,1979.0,1980.0,1981.0,1982.0,1983.0,1984.0,1985.0,1986.0,1987.0,1988.0,1989.0,1990.0,1991.0,1992.0,1993.0,1994.0,1995.0,1996.0,1997.0,1998.0,1999.0,2000.0,2001.0,2002.0,2003.0,2004.0,2005.0,2006.0,2007.0,2008.0,2009.0,2010.0,2011.0,2012.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0],"legendgroup":"","marker":{"color":[-0.157,-0.072,-0.097,-0.162,-0.277,-0.325,-0.305,-0.354,-0.167,-0.102,-0.345,-0.222,-0.269,-0.309,-0.299,-0.22,-0.108,-0.105,-0.264,-0.169,-0.073,-0.148,-0.269,-0.36,-0.46,-0.256,-0.217,-0.378,-0.42,-0.477,-0.424,-0.431,-0.349,-0.337,-0.144,-0.133,-0.349,-0.45,-0.29,-0.269,-0.266,-0.183,-0.278,-0.26,-0.265,-0.215,-0.104,-0.215,-0.196,-0.356,-0.155,-0.092,-0.16,-0.286,-0.122,-0.198,-0.148,-0.026,-0.003,-0.018,0.125,0.185,0.065,0.088,0.203,0.09,-0.074,-0.028,-0.107,-0.109,-0.174,-0.069,0.011,0.079,-0.132,-0.141,-0.189,0.047,0.06,0.03,-0.025,0.057,0.031,0.054,-0.2,-0.107,-0.055,-0.023,-0.084,0.055,0.025,-0.082,0.008,0.161,-0.068,-0.014,-0.097,0.178,0.068,0.165,0.259,0.322,0.141,0.314,0.157,0.118,0.18,0.323,0.39,0.273,0.452,0.406,0.22,0.234,0.316,0.446,0.328,0.464,0.609,0.383,0.395,0.54,0.628,0.62,0.539,0.682,0.643,0.668,0.546,0.66,0.725,0.61,0.646,0.682,0.751,0.901,1.018,0.926,0.853,0.986,1.022],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","r":[-0.157,-0.072,-0.097,-0.162,-0.277,-0.325,-0.305,-0.354,-0.167,-0.102,-0.345,-0.222,-0.269,-0.309,-0.299,-0.22,-0.108,-0.105,-0.264,-0.169,-0.073,-0.148,-0.269,-0.36,-0.46,-0.256,-0.217,-0.378,-0.42,-0.477,-0.424,-0.431,-0.349,-0.337,-0.144,-0.133,-0.349,-0.45,-0.29,-0.269,-0.266,-0.183,-0.278,-0.26,-0.265,-0.215,-0.104,-0.215,-0.196,-0.356,-0.155,-0.092,-0.16,-0.286,-0.122,-0.198,-0.148,-0.026,-0.003,-0.018,0.125,0.185,0.065,0.088,0.203,0.09,-0.074,-0.028,-0.107,-0.109,-0.174,-0.069,0.011,0.079,-0.132,-0.141,-0.189,0.047,0.06,0.03,-0.025,0.057,0.031,0.054,-0.2,-0.107,-0.055,-0.023,-0.084,0.055,0.025,-0.082,0.008,0.161,-0.068,-0.014,-0.097,0.178,0.068,0.165,0.259,0.322,0.141,0.314,0.157,0.118,0.18,0.323,0.39,0.273,0.452,0.406,0.22,0.234,0.316,0.446,0.328,0.464,0.609,0.383,0.395,0.54,0.628,0.62,0.539,0.682,0.643,0.668,0.546,0.66,0.725,0.61,0.646,0.682,0.751,0.901,1.018,0.926,0.853,0.986,1.022],"showlegend":false,"subplot":"polar","type":"barpolar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"sol ...

# %% [markdown]
# [Plotly Ref](https://plotly.com/python-api-reference/generated/plotly.graph_objects.layout.polar.html)

# %%
import plotly

# %%
plotly.offline.plot(fig, filename='temperature.html')
# Out:
# 'temperature.html'
